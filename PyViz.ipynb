# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
#create a line plot:
x= [1,2,3,4,5,6,7]
y= [2,4,6,8,10,12,14]
plt.plot(x,y)
plt.xlabel("Num")
plt.ylabel("Doubler")
plt.show()
